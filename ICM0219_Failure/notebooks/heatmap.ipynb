# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from pylab import *
# data=pd.read_csv('./subub.csv',header=None)
# # data = data.apply(lambda x:(x-np.min(x))/(np.max(x)-np.min(x)))
# # res = data.var()
# data_selected_by_var = [1,2,3,4,5,6,7]
# corr= data[data_selected_by_var].corr()
# ax=sns.heatmap(corr,vmax=1,vmin=-1)
# map_vir = cm.get_cmap('Pastel1')
# # plt.imshow(camp=map_vir)
# plt.show()

data=np.zeros((8,8))
list = [1,0.59,0.4,0.2,0.3,0.5,0.4,0.6,
        1,0.2,0.7,0.5,0.4,0.85,0.1,
        1,0.3,0.9,0.2,0.25,0.63,
        1,0.1,0.3,0.7,0.5,
        1,0.5,0.25,0.15,
        1,0.42,0.24,
        1,0.11,
        1]
k = 0
for i in range(0,8):
    for j in range(i,8):
        data[i,j] = list[k]
        data[j,i] = list[k]
        k+=1
# plt.imshow(data)
# plt.colorbar()
# plt.grid(False)
ax=sns.heatmap(data,vmax=1.0,vmin=0)
plt.xticks(range(8),['         NIL','         PD','         VC','         BS','         LA','         CR','         GDP','         AST'])
# plt.xticks(range(8),['NIL','PD','VC','BS','LA','CR','GDP','AST'])
plt.yticks(range(8),['NIL         ','PD         ','VC         ','BS         ','LA         ','CR         ','GDP         ','AST         '])
plt.savefig("heatmap.svg",format='svg')
plt.show()
